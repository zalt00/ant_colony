# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
datas0 = datas

# %%
with open("trace.json", "r") as file:
    datas = json.load(file)

# %%
for data in data0:
    data = np.array(data)
    plt.plot(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 for data in data0:
#       2     data = np.array(data)
#       3     plt.plot(data)
#
# NameError: name 'data0' is not defined

# %%
for data in datas:
    data = np.array(data)
    plt.plot(data)

# %%
for data in datas+datas0:
    data = np.array(data)
    plt.plot(data)

# %%
for data in datas:
    data = np.array(data)
    plt.plot(data)
