# %%
import json
import matplotlib.pyplot as plt
import numpy as np
datas = []

# %%
with open("trace.json", "r") as file:
    data = json.load(file)
    data = np.array(data)
    datas.append(data)

# %%
plt.plot(datas[-1])
plt.plot(datas[-2])

# %%
plt.plot(data)
