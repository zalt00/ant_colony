# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
with open("trace.json", "r") as file:
    data = json.load(file)

# %%
data = np.array(data)

# %%
plt.plot(data)

# %%
plt.plot(data)
